# %%
import os
import re
import requests
import threading
import time
import urllib3
import urllib.error
import urllib.request
import threading
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from urllib.request import urlretrieve

# Colocar o nome do curso aqui
course = 'deep-learning-reinforcement-learning'

# Função para limpar o nome da pasta
def limpar_nome_pasta(nome):
    return re.sub(r'[\\/*?"<>|:]', '', nome)

# Função para fazer download em outro processo
def download_arquivo(file_url, file_path, tentativas=3):
    def download_interno():
        tentativa = 0
        while tentativa < tentativas:
            try:
                urllib.request.urlretrieve(file_url, file_path)
                break
            except urllib.error.ContentTooShortError as e:
                tentativa += 1
                if tentativa == tentativas:
                    print('Falha no download após várias tentativas')
                    print(f'Arquivo: {file_path}')
                    print(f'Link: {file_url}')
                    print(f'Erro: {e}')
    
    thread = threading.Thread(target=download_interno)
    thread.start()

# Função para aguardar página carregar
def aguardar_pagina_carregar(navegador, tempo_maximo=120):
    WebDriverWait(navegador, tempo_maximo).until(
        lambda d: d.execute_script('return document.readyState') == 'complete'
    )
    time.sleep(10)

# %%
# Carrega o WebDriver com o navegador (Edge ou Chrome)
navegador = webdriver.Edge()

# Prepara o action
action = ActionChains(navegador)

# Maximiza a janela do navegador
navegador.maximize_window()

# Pasta de downloads
pasta_downloads = os.path.join('..', 'downloads')

# Acessa página de login do Coursera
navegador.get('https://www.coursera.org/?authMode=login')

# Espera pelo login ser realizado
try:
    WebDriverWait(navegador, 120).until(
        EC.presence_of_element_located((By.CSS_SELECTOR, "li.rc-AuthenticatedAccountDropdown"))
    )

except TimeoutException:
    print('Login não realizado')
    os._exit(0)

# %%
# Vai para página do curso
navegador.get(f'https://www.coursera.org/learn/{course}/home/welcome')

# Espera pelo pop-up de tradução automática
try:
    WebDriverWait(navegador, 10).until(
        EC.presence_of_element_located((By.CSS_SELECTOR, "div[aria-modal='true']"))
    )
    popup = navegador.find_element(By.CSS_SELECTOR, "div[aria-modal='true']")
    botao_continuar = popup.find_element(By.CSS_SELECTOR, "button[class*='cds-button-primary']")
    botao_continuar.click()

except TimeoutException:
    pass

# Aguarda a página carregar completamente
aguardar_pagina_carregar(navegador)

# Encontra o menu lateral
sider_menu = navegador.find_element(By.CSS_SELECTOR, '[data-e2e="courseNavigation"]')

# Encontra o instituição
institution = sider_menu.find_element(By.TAG_NAME, 'p').text
print(f'Instituição: {institution}')

# Caminho para a pasta da instituição dentro de "downloads"
caminho_institution = os.path.join(pasta_downloads, limpar_nome_pasta(institution))

# Cria a pasta se ela não existir
if not os.path.exists(caminho_institution):
    os.makedirs(caminho_institution)

# Encontra o título do curso
course_title = sider_menu.find_element(By.TAG_NAME, 'h2').get_attribute('title')
print(f'Curso: {course_title}')

# Caminho para a pasta do curso dentro da instituição
caminho_course = os.path.join(caminho_institution, limpar_nome_pasta(course_title))

# Cria a pasta se ela não existir
if not os.path.exists(caminho_course):
    os.makedirs(caminho_course)

# Seleciona o container específico onde os links estão localizados
accordion_container = sider_menu.find_element(By.TAG_NAME, 'nav')
accordion_container = accordion_container.find_element(By.CSS_SELECTOR, '[data-test="rc-WeekCollectionNavigationItem"]')
accordion_container = accordion_container.find_element(By.TAG_NAME, 'ul')

# Busca todos os elementos <a> dentro do container específico
week_elements = accordion_container.find_elements(By.TAG_NAME, 'a')

# Lista para armazenar os pares (descrição da semana, href)
week_info = []

# Itera sobre os elementos encontrados
for week_element in week_elements:
    week = week_element.get_attribute('aria-label').split('.')[0]
    w_href = week_element.get_attribute('href')
    if w_href:
        week_info.append((week, w_href))
print(week_info)
# Out:
# Instituição: IBM
# Curso: Aprendizagem profunda e aprendizagem por reforço
# [('Semana 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/1'), ('Semana 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/2'), ('Semana 3', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/3'), ('Semana 4', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/4'), ('Semana 5', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/5'), ('Semana 6', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/6'), ('Semana 7', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/7'), ('Semana 8', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/8'), ('Semana 9', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/home/week/9')]

# %%
# Faz o loop nos módulos
for week, w_href in week_info:
    try:
        # Caminho para a pasta do módulo dentro do curso
        caminho_week = os.path.join(caminho_course, limpar_nome_pasta(week))
        print(f'Módulo: {week}')
    
        # Cria a pasta se ela não existir
        if not os.path.exists(caminho_week):
            os.makedirs(caminho_week)
    
        # Navega até a semana 
        navegador.get(w_href)
        
        # Aguarda a página carregar completamente
        aguardar_pagina_carregar(navegador)

        # Aguarda carregar o container do conteúdo do módulo
        WebDriverWait(navegador, 15).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, "div.rc-ModuleLessons"))
        )
        
        # Seleciona o container específico onde os links estão localizados
        module_section_container = navegador.find_element(By.CSS_SELECTOR, "div.rc-ModuleLessons")

        # Aguarde até que os botões do acordeão estejam visíveis e depois colete-os
        accordion_buttons = WebDriverWait(module_section_container, 10).until(
            EC.presence_of_all_elements_located((By.CSS_SELECTOR, ".cds-AccordionHeader-button"))
        )

        # Clique em cada botão do acordeão para expandir as seções, se não estiverem já expandidas
        for button in accordion_buttons:
            aria_expanded = button.get_attribute('aria-expanded')
            if aria_expanded == "false":
                button.click()
    
        # Busca todos os elementos <a> dentro do container
        lesson_elements = module_section_container.find_elements(By.TAG_NAME, 'a')
        
        # Lista para armazenar os pares (descrição da aula, href)
        lesson_info = []

        # Itera sobre os elementos encontrados
        for lesson_element in lesson_elements:
            lesson = lesson_element.find_element(By.TAG_NAME, 'p').text
            l_href = lesson_element.get_attribute('href')
            if l_href:
                lesson_info.append((lesson, l_href))
        print(lesson_info)
    
        # Faz o loop nas aulas
        for index, (lesson, l_href) in enumerate(lesson_info, start=1):
            try:
                # Caminho para a pasta da aula dentro do módulo
                caminho_lesson = os.path.join(caminho_week, limpar_nome_pasta(f'{index:02d} - {lesson}'))
                print(f'Aula: {index:02d} - {lesson}')
                
                # Cria a pasta se ela não existir
                if not os.path.exists(caminho_lesson):
                    os.makedirs(caminho_lesson)
                
                # Navega até a aula
                navegador.get(l_href)
                
                # Aguarda a página carregar completamente
                aguardar_pagina_carregar(navegador)

                # Pressiona esc para possíveis popups
                action.send_keys(Keys.ESCAPE).perform()
                
                # Procura pelo elemento main na página
                main_element = navegador.find_element(By.TAG_NAME, 'main')
                
                ############ Arquivos txt ############
                # Extrai todo o texto dentro do elemento main
                main_text = main_element.text
                
                # Escreve o texto no arquivo
                with open(os.path.join(caminho_lesson, limpar_nome_pasta(f'{index:02d} - {lesson}.txt')), 'w', encoding='utf-8') as arquivo:
                    arquivo.write(main_text)
                
                ############ Arquivos anexados ############
                # Procura por todos os elementos com data-extension dentro do main_element
                file_elements = main_element.find_elements(By.XPATH, '//*[@data-extension]')
                
                # Faz o download dos arquivos encontrados
                for element in file_elements:
                    file_url = element.get_attribute('data-url')
                    file_name = element.get_attribute('data-name')
                    file_extetion = element.get_attribute('data-extension')
                    download_arquivo(file_url, os.path.join(caminho_lesson, limpar_nome_pasta(file_name)))
                    print(f'Encontrou arquivo {file_extetion}')

                ############ Arquivos de laboratório ############
                # Verifica se a div com a classe 'rc-UngradedLabLauncher' está presente
                if main_element.find_elements(By.CLASS_NAME, 'rc-UngradedLabLauncher') or main_element.find_elements(By.CSS_SELECTOR, 'button[data-track-component="programming_lab_launch_button"]'):
                
                    # Pega a URL atual e adiciona '/lab' ao final da URL
                    lab_url = navegador.current_url + '/lab'
                
                    # Abre uma nova guia e vai para a URL modificada
                    navegador.execute_script("window.open('');")
                    navegador.switch_to.window(navegador.window_handles[1])
                    navegador.get(lab_url)
                
                    # Aguarda a página carregar completamente
                    aguardar_pagina_carregar(navegador)

                    # Espera até que o iframe com o título "lab" esteja presente na página
                    WebDriverWait(navegador, 60).until(
                        EC.presence_of_element_located((By.XPATH, '//iframe[@title="lab"]'))
                    )
                
                    # Procura pelo iframe com o title 'lab'
                    iframe_element = navegador.find_element(By.XPATH, '//iframe[@title="lab"]')
                    
                    # Pega a URL do atributo src do iframe
                    iframe_url = iframe_element.get_attribute('src')
                    
                    # Realiza o download do jupyter notebook
                    download_arquivo(iframe_url, os.path.join(caminho_lesson, limpar_nome_pasta(iframe_url.split("/")[-1])))
                    print(f'Encontrou arquivo {iframe_url.split(".")[-1]}')

                    # Extrai a parte específica da URL que representa a sessão
                    url_lab = f'https://hub.labs.coursera.org/api/workspaceFileBrowser.v1/{iframe_url.split("//")[1].split(".")[0]}?command=Download&arguments=[]'

                    # Faz o download do lab completo
                    download_arquivo(
                        url_lab,
                        os.path.join(caminho_lesson, limpar_nome_pasta(f'{index:02d} - {lesson}.zip'))
                    )
                    navegador.get(url_lab)
                    
                    # Aguarda a página carregar completamente
                    aguardar_pagina_carregar(navegador)

                    # Pressiona esc para possíveis abas de download
                    action.send_keys(Keys.ESCAPE).perform()
                    
                    # Fecha guia atual e volta para guia anterior
                    navegador.close()
                    navegador.switch_to.window(navegador.window_handles[0])
                
                ############ Arquivo de vídeo ############
                # Navega até a aba Downloads
                downloads_tab = WebDriverWait(main_element, 10).until(
                    EC.element_to_be_clickable((By.CSS_SELECTOR, '[data-testid="tabs-root"] button[data-track-component="focused_lex_lecture_tabs_download"]'))
                )
                downloads_tab.click()
                
                # Seleciona o container específico onde os links estão localizados
                downloads_container = main_element.find_element(By.CSS_SELECTOR, '[id$="-panel-DOWNLOADS"]')
                
                # Busca todos os links dentro do container específico
                content_links = downloads_container.find_elements(By.TAG_NAME, "a")
                
                # Busca todos os links dentro do container específico e armazena os hrefs
                content_hrefs = [c_link.get_attribute('href') for c_link in content_links if c_link.get_attribute('href')]
                
                # Faz o download do vídeo
                for c_href in content_hrefs:
                    # Iniciando varredura nos conteúdos
                    if ".mp4" in c_href and "720p" in c_href:
                        # Faz o download do arquivo
                        download_arquivo(c_href, os.path.join(caminho_lesson, limpar_nome_pasta(f'{index:02d} - {lesson}.mp4')))
                        print('Encontrou vídeo')
                        break

                ############ Arquivo de legenda ############
                # Encontrar todos os elementos <track> no vídeo
                track_elements = main_element.find_elements(By.TAG_NAME, "track")
                
                # Faz o download da legenda em pt-BR
                for track in track_elements:
                    if 'Português (Brasil)' in track.get_attribute('label') and 'vtt' in track.get_attribute('src'):
                        download_arquivo(
                            track.get_attribute('src'),
                            os.path.join(caminho_lesson, limpar_nome_pasta(f'{index:02d} - {lesson}.vtt'))
                        )
                        print('Encontrou legenda')
                        break
                
            except TimeoutException:
                # Se acontecer exceção vai para a próxima aula
                pass
    except TimeoutException:
        # Se acontecer exceção vai para o próximo módulo
        pass

# Encerra o processo
navegador.quit()
print('Fim do processo')
# Out:
# Módulo: Semana 1
# [('Introdução ao curso', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/tgTfs/course-introduction'), ('Introdução às redes neurais', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/VVfGh/introduction-to-neural-networks'), ('Noções básicas de neurônios', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/yRieI/basics-of-neurons'), ('Redes neurais com o Sklearn', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/VqDFn/neural-networks-with-sklearn'), ('Neurônio em ação', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/A09cN/neuron-in-action'), ('Redes neurais com SKlearn', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/XQsxv/neural-networks-with-sklearn'), ('Redes neurais com o Sklearn', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/E03Ka/neural-networks-with-sklearn'), ('Propagação direta', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/5o9Nk/forward-propagation'), ('Representação matricial da propagação direta', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ydmR9/matrix-representation-of-forward-propagation'), ('Principais tipos de redes neurais profundas', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/b5j1c/main-types-of-deep-neural-network'), ('Demonstração de introdução às redes neurais (atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/vWwXB/introduction-to-neural-networks-demo-activity'), ('(Opcional) Caderno de Introdução às Redes Neurais - Parte 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/jJd6M/optional-introduction-to-neural-networks-notebook-part-1'), ('(Opcional) Caderno de Introdução às Redes Neurais - Parte 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/YmceA/optional-introduction-to-neural-networks-notebook-part-2'), ('Prática: Introdução às redes neurais', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/jsHcW/practice-introduction-to-neural-networks'), ('Noções básicas de Gradient Descent', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/lkXEk/gradient-descent-basics'), ('Comparar diferentes métodos de gradiente descendente', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ZiEWv/compare-different-gradient-descent-methods'), ('Demonstração do Gradient Descent (Atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/00WHS/gradient-descent-demo-activity'), ('(Opcional) Caderno de anotações do Gradient Descent - Parte 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ntadl/optional-gradient-descent-notebook-part-1'), ('(Opcional) Caderno de anotações do Gradient Descent - Parte 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/i9ACn/optional-gradient-descent-notebook-part-2'), ('(Opcional) Caderno de anotações do Gradient Descent - Parte 3', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ZNh0x/optional-gradient-descent-notebook-part-3'), ('Prática: Otimização e descida de gradiente', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/9LgbC/practice-optimization-and-gradient-descent'), ('Resumo/Revisão', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/MOgz9/summary-review'), ('Questionário de final de módulo', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/exam/WWdKe/end-of-module-quiz')]
# Aula: 01 - Introdução ao curso
# Encontrou vídeo
# Encontrou legenda
# Aula: 02 - Introdução às redes neurais
# Encontrou vídeo
# Encontrou legenda
# Aula: 03 - Noções básicas de neurônios
# Encontrou vídeo
# Encontrou legenda
# Aula: 04 - Redes neurais com o Sklearn
# Encontrou vídeo
# Encontrou legenda
# Aula: 05 - Neurônio em ação
# Encontrou vídeo
# Encontrou legenda
# Aula: 06 - Redes neurais com SKlearn
# Encontrou vídeo
# Encontrou legenda
# Aula: 07 - Redes neurais com o Sklearn
# Aula: 08 - Propagação direta
# Encontrou vídeo
# Encontrou legenda
# Aula: 09 - Representação matricial da propagação direta
# Encontrou vídeo
# Encontrou legenda
# Aula: 10 - Principais tipos de redes neurais profundas
# Encontrou vídeo
# Encontrou legenda
# Aula: 11 - Demonstração de introdução às redes neurais (atividade)
# Aula: 12 - (Opcional) Caderno de Introdução às Redes Neurais - Parte 1
# Encontrou vídeo
# Encontrou legenda
# Aula: 13 - (Opcional) Caderno de Introdução às Redes Neurais - Parte 2
# Encontrou vídeo
# Encontrou legenda
# Aula: 14 - Prática: Introdução às redes neurais
# Aula: 15 - Noções básicas de Gradient Descent
# Encontrou vídeo
# Encontrou legenda
# Aula: 16 - Comparar diferentes métodos de gradiente descendente
# Encontrou vídeo
# Encontrou legenda
# Aula: 17 - Demonstração do Gradient Descent (Atividade)
# Aula: 18 - (Opcional) Caderno de anotações do Gradient Descent - Parte 1
# Encontrou vídeo
# Encontrou legenda
# Aula: 19 - (Opcional) Caderno de anotações do Gradient Descent - Parte 2
# Encontrou vídeo
# Encontrou legenda
# Aula: 20 - (Opcional) Caderno de anotações do Gradient Descent - Parte 3
# Encontrou vídeo
# Encontrou legenda
# Aula: 21 - Prática: Otimização e descida de gradiente
# Aula: 22 - Resumo/Revisão
# Aula: 23 - Questionário de final de módulo
# Módulo: Semana 2
# [('Como treinar uma rede neural', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/TTkmP/how-to-train-a-neural-network'), ('Retropropagação', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/EblkM/backpropagation'), ('Demonstração de retropropagação (atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/eUb6D/backpropagation-demo-activity'), ('(Opcional) Notebook de retropropagação - Parte 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/1wVUB/optional-backpropagation-notebook-part-1'), ('(Opcional) Notebook de retropropagação - Parte 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/WZUot/optional-backpropagation-notebook-part-2'), ('A função de ativação do sigmoide', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/8vd2T/the-sigmoid-activation-function'), ('Outras funções de ativação populares', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/jxcWS/other-popular-activation-functions'), ('(Opcional) Notebook de retropropagação - Parte 3', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/tPizy/optional-backpropagation-notebook-part-3'), ('Prática: Propagação posterior, funções de ativação', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/sdCEm/practice-back-propagation-activation-functions'), ('Biblioteca popular de aprendizagem profunda', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/bwj2q/popular-deep-learning-library'), ('Um fluxo de trabalho típico do Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/D9buX/a-typical-keras-workflow'), ('Implementação de uma rede neural de exemplo no Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/2h9zz/implementing-an-example-neural-network-in-keras'), ('Demonstração do Keras (atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/awBvQ/keras-demo-activity'), ('(Opcional) Notebook do Keras - Parte 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ZK1cR/optional-keras-notebook-part-1'), ('(Opcional) Notebook do Keras - Parte 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/Dux07/optional-keras-notebook-part-2'), ('(Opcional) Notebook do Keras - Parte 3', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/y2ef3/optional-keras-notebook-part-3'), ('Regressão com o Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/W3g1J/regression-with-keras'), ('(Opcional) Carregamento de imagens com o Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/U1thD/optional-loading-images-with-keras'), ('Prática: Biblioteca Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/HqU8n/practice-keras-library'), ('Resumo/Revisão', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/6N9Ic/summary-review'), ('Questionário de final de módulo', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/exam/ExENp/end-of-module-quiz')]
# Aula: 01 - Como treinar uma rede neural
# Encontrou vídeo
# Encontrou legenda
# Aula: 02 - Retropropagação
# Encontrou vídeo
# Encontrou legenda
# Aula: 03 - Demonstração de retropropagação (atividade)
# Aula: 04 - (Opcional) Notebook de retropropagação - Parte 1
# Encontrou vídeo
# Encontrou legenda
# Aula: 05 - (Opcional) Notebook de retropropagação - Parte 2
# Encontrou vídeo
# Encontrou legenda
# Aula: 06 - A função de ativação do sigmoide
# Encontrou vídeo
# Encontrou legenda
# Aula: 07 - Outras funções de ativação populares
# Encontrou vídeo
# Encontrou legenda
# Aula: 08 - (Opcional) Notebook de retropropagação - Parte 3
# Encontrou vídeo
# Encontrou legenda
# Aula: 09 - Prática: Propagação posterior, funções de ativação
# Aula: 10 - Biblioteca popular de aprendizagem profunda
# Encontrou vídeo
# Encontrou legenda
# Aula: 11 - Um fluxo de trabalho típico do Keras
# Encontrou vídeo
# Encontrou legenda
# Aula: 12 - Implementação de uma rede neural de exemplo no Keras
# Encontrou vídeo
# Encontrou legenda
# Aula: 13 - Demonstração do Keras (atividade)
# Encontrou arquivo csv
# Aula: 14 - (Opcional) Notebook do Keras - Parte 1
# Encontrou vídeo
# Encontrou legenda
# Aula: 15 - (Opcional) Notebook do Keras - Parte 2
# Encontrou vídeo
# Encontrou legenda
# Aula: 16 - (Opcional) Notebook do Keras - Parte 3
# Encontrou vídeo
# Encontrou legenda
# Aula: 17 - Regressão com o Keras
# Aula: 18 - (Opcional) Carregamento de imagens com o Keras
# Aula: 19 - Prática: Biblioteca Keras
# Aula: 20 - Resumo/Revisão
# Aula: 21 - Questionário de final de módulo
# Módulo: Semana 3
# [('Otimizadores e Momentum', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/TuZPu/optimizers-and-momentum'), ('Otimizadores populares', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/9KxIs/popular-optimizers'), ('Detalhes do treinamento de redes neurais', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/HR1Le/details-of-training-neural-networks'), ('Leitura do programador da taxa de aprendizado', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedWidget/bbznS/learning-rate-scheduler-reading'), ('Embaralhamento de dados', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/E32kN/data-shuffling'), ('Otimizadores', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/FV102/optimizers'), ('Pesquisa de grade com o Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/67XjD/grid-search-with-keras'), ('Transformações', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/ZPtvt/transforms'), ('Prática: Otimizadores e embaralhamento de dados', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/R1vgQ/practice-optimizers-and-data-shuffling'), ('Resumo/Revisão', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/BFNil/summary-review'), ('Questionário de final de módulo', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/exam/OE3MB/end-of-module-quiz')]
# Aula: 01 - Otimizadores e Momentum
# Encontrou vídeo
# Encontrou legenda
# Aula: 02 - Otimizadores populares
# Encontrou vídeo
# Encontrou legenda
# Aula: 03 - Detalhes do treinamento de redes neurais
# Encontrou vídeo
# Encontrou legenda
# Aula: 04 - Leitura do programador da taxa de aprendizado
# Aula: 05 - Embaralhamento de dados
# Encontrou vídeo
# Encontrou legenda
# Aula: 06 - Otimizadores
# Aula: 07 - Pesquisa de grade com o Keras
# Aula: 08 - Transformações
# Encontrou vídeo
# Encontrou legenda
# Aula: 09 - Prática: Otimizadores e embaralhamento de dados
# Aula: 10 - Resumo/Revisão
# Aula: 11 - Questionário de final de módulo
# Módulo: Semana 4
# [('Entropia cruzada categórica', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/N5GTC/categorical-cross-entropy'), ('Entropia cruzada categórica', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/IuJN5/categorical-cross-entropy'), ('Introdução às redes neurais convolucionais (CNN)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/VCz3o/introduction-to-convolutional-neural-networks-cnn'), ('Conjunto de dados de imagens', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/VSpWy/images-dataset'), ('Núcleos', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/PASsV/kernels'), ('Convolução para imagens coloridas', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/mwbAj/convolution-for-color-images'), ('Convolução de imagens', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/o4yjA/images-convolution'), ('Configurações convolucionais - Padding e Stride', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/YUl5F/convolutional-settings-padding-and-stride'), ('Acolchoamento, agrupamento e passada', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/cboNm/padding-pooling-and-stride'), ('Configurações convolucionais - profundidade e pooling', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/I9ltn/convolutional-settings-depth-and-pooling'), ('Canais e achatamento', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/ZPRDR/channels-and-flattening'), ('Treinamento da rede', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/9nsuf/training-the-network'), ('Demonstração de redes neurais convolucionais (atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/D8p2S/convolutional-neural-networks-demo-activity'), ('(Opcional) Demonstração do CNN Notebook - Parte 1', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/5VLDF/optional-demo-cnn-notebook-part-1'), ('(Opcional) Demonstração do CNN Notebook - Parte 2', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/pVgfg/optional-demo-cnn-notebook-part-2'), ('Prática: Redes neurais convolucionais', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/NT2Il/practice-convolutional-neural-networks'), ('Resumo/Revisão', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/SVmmG/summary-review'), ('Questionário de final de módulo', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/exam/cPLyc/end-of-module-quiz')]
# Aula: 01 - Entropia cruzada categórica
# Encontrou vídeo
# Encontrou legenda
# Aula: 02 - Entropia cruzada categórica
# Aula: 03 - Introdução às redes neurais convolucionais (CNN)
# Encontrou vídeo
# Encontrou legenda
# Aula: 04 - Conjunto de dados de imagens
# Encontrou vídeo
# Encontrou legenda
# Aula: 05 - Núcleos
# Encontrou vídeo
# Encontrou legenda
# Aula: 06 - Convolução para imagens coloridas
# Encontrou vídeo
# Encontrou legenda
# Aula: 07 - Convolução de imagens
# Aula: 08 - Configurações convolucionais - Padding e Stride
# Encontrou vídeo
# Encontrou legenda
# Aula: 09 - Acolchoamento, agrupamento e passada
# Aula: 10 - Configurações convolucionais - profundidade e pooling
# Encontrou vídeo
# Encontrou legenda
# Aula: 11 - Canais e achatamento
# Aula: 12 - Treinamento da rede
# Aula: 13 - Demonstração de redes neurais convolucionais (atividade)
# Aula: 14 - (Opcional) Demonstração do CNN Notebook - Parte 1
# Encontrou vídeo
# Encontrou legenda
# Aula: 15 - (Opcional) Demonstração do CNN Notebook - Parte 2
# Encontrou vídeo
# Encontrou legenda
# Aula: 16 - Prática: Redes neurais convolucionais
# Aula: 17 - Resumo/Revisão
# Aula: 18 - Questionário de final de módulo
# Módulo: Semana 5
# [('Introdução à aprendizagem por transferência', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/b87WK/introduction-to-transfer-learning'), ('Aprendizagem por transferência e ajuste fino', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/Pc8WC/transfer-learning-and-fine-tuning'), ('Demonstração de aprendizagem por transferência (atividade)', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/Qr1AZ/transfer-learning-demo-activity'), ('(Opcional) Caderno de aprendizagem de transferência', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/sDhpa/optional-transfer-learning-notebook'), ('Prática: Aprendizagem por transferência', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/xEb9J/practice-transfer-learning'), ('Arquiteturas de redes neurais convolucionais - LeNet', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/cDqhm/convolutional-neural-network-architectures-lenet'), ('Arquiteturas de redes neurais convolucionais - AlexNet', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/oAc6X/convolutional-neural-network-architectures-alexnet'), ('Arquiteturas de redes neurais convolucionais - Inception', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/yCXHR/convolutional-neural-network-architectures-inception'), ('Arquiteturas de redes neurais convolucionais - ResNet', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/g5eJq/convolutional-neural-network-architectures-resnet'), ('Tipos de APIs de modelo no Keras', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/SbunY/types-of-model-apis-in-keras'), ('Exemplos de aprendizagem por transferência com arquiteturas existentes', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/rVSgO/transfer-learning-examples-with-existing-architectures'), ('Prática: Arquiteturas de redes neurais convolucionais', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/2TbSI/practice-convolutional-neural-network-architectures'), ('Técnicas de regularização para aprendizagem profunda', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/lecture/Lamgl/regularization-techniques-for-deep-learning'), ('Leitura de regularização', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedWidget/51t3O/regularization-reading'), ('Técnicas de regularização', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/ungradedLti/La2md/regularization-techniques'), ('Prática: Regularização', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/quiz/O88ua/practice-regularization'), ('', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/supplement/aKwLk/summary-review'), ('', 'https://www.coursera.org/learn/deep-learning-reinforcement-learning/exam/ocEvd/end-of-module-quiz')]
# Aula: 01 - Introdução à aprendizagem por transferência
# Encontrou vídeo
# Encontrou legenda
# Aula: 02 - Aprendizagem por transferência e ajuste fino
# Encontrou vídeo
# Encontrou legenda
# Aula: 03 - Demonstração de aprendizagem por transferência (atividade)
# Aula: 04 - (Opcional) Caderno de aprendizagem de transferência
# Encontrou vídeo
# Encontrou legenda
# Aula: 05 - Prática: Aprendizagem por transferência
# Aula: 06 - Arquiteturas de redes neurais convolucionais - LeNet
# Encontrou vídeo
# Encontrou legenda
# Aula: 07 - Arquiteturas de redes neurais convolucionais - AlexNet
# Encontrou vídeo
# Encontrou legenda
# Aula: 08 - Arquiteturas de redes neurais convolucionais - Inception
# Encontrou vídeo
# Encontrou legenda
# Aula: 09 - Arquiteturas de redes neurais convolucionais - ResNet
# Encontrou vídeo
# Encontrou legenda
# Aula: 10 - Tipos de APIs de modelo no Keras
# Aula: 11 - Exemplos de aprendizagem por transferência com arquiteturas existentes
# Aula: 12 - Prática: Arquiteturas de redes neurais convolucionais
# Aula: 13 - Técnicas de regularização para aprendizagem profunda
# Encontrou vídeo
# Encontrou legenda
# Aula: 14 - Leitura de regularização
# Aula: 15 - Técnicas de regularização
# Aula: 16 - Prática: Regularização
# Aula: 17 -
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 79
#      76 main_text = main_element.text
#      78 # Escreve o texto no arquivo
# ---> 79 with open(os.path.join(caminho_lesson, limpar_nome_pasta(f'{index:02d} - {lesson}.txt')), 'w', encoding='utf-8') as arquivo:
#      80     arquivo.write(main_text)
#      82 ############ Arquivos anexados ############
#      83 # Procura por todos os elementos com data-extension dentro do main_element
#
# File ~\Documents\Visual Studio\download-coursera\venv\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\downloads\\IBM\\Aprendizagem profunda e aprendizagem por reforço\\Semana 5\\17 - \\17 - .txt'
